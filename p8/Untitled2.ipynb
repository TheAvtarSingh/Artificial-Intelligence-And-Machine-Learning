# %%
#IMPORTING LIBRARIES

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#calculating mean squaed error
from sklearn.metrics import mean_squared_error

#creating a dataset
x = 100*np.random.normal(0,1,200)
y = 100*(-x**2)+np.random.normal(-100,100,200)

#plotting dataset
plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.show()

# %%
# Importing Linear Regression
from sklearn.linear_model import LinearRegression

# Training Model
lm=LinearRegression()
lm.fit(x.reshape(-1,1),y.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred=lm.predict(x.reshape(-1,1))

# plotting predictions
plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.plot(x,y_pred,color='r')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.show()

# %%
print('RMSE for Linear Regression=>',np.sqrt(mean_squared_error(y,y_pred)))
# Out:
# RMSE for Linear Regression=> 1151952.2508884065

# %%
# importing libraries for polynomial transform
from sklearn.preprocessing import PolynomialFeatures
# for creating pipeline
from sklearn.pipeline import Pipeline
# creating pipeline and fitting it on data
Input=[('polynomial',PolynomialFeatures(degree=2)),('modal',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(x.reshape(-1,1),y.reshape(-1,1))
# Out:
# Pipeline(steps=[('polynomial', PolynomialFeatures()),
#                 ('modal', LinearRegression())])

# %%
poly_pred=pipe.predict(x.reshape(-1,1))
#sorting predicted values with respect to predictor
sorted_zip = sorted(zip(x,poly_pred))
x_poly, poly_pred = zip(*sorted_zip)
#plotting predictions
plt.figure(figsize=(10,6))
plt.scatter(x,y,s=15)
#plt.plot(x,y_pred,color='r',label='Linear Regression')
plt.plot(x_poly,poly_pred,color='g',label='Polynomial Regression')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.legend()
plt.show()

# %%
print('RMSE for Polynomial Regression=>',np.sqrt(mean_squared_error(y,poly_pred)))
# Out:
# RMSE for Polynomial Regression=> 1709837.2026359804
